# %%
# %config Completer.use_jedi = False

# %%
# data analysis
import numpy as np
import pandas as pd

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Forecasting
from fbprophet import Prophet
from fbprophet.plot import plot_plotly, plot_components_plotly
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
cash = pd.read_csv('train.csv')
cash.head()
# Out:
#       periode  cash_in_echannel  cash_out_echannel  cash_in_kantor  \
# 0  2019-07-31      7.303000e+08      -1.304400e+09    1.436722e+11
# 1  2019-08-01      7.322000e+08      -8.321500e+08    3.144131e+11
# 2  2019-08-02      1.169800e+09      -6.214000e+08    1.251294e+09
# 3  2019-08-03      9.134500e+08      -4.240500e+08    0.000000e+00
# 4  2019-08-04      7.752500e+08      -7.779500e+08    9.883331e+10
#
#    cash_out_kantor  cr_ketetapan_total_bkn_sum          giro      deposito  \
# 0    -1.106104e+11                         3.0  9.867358e+11  8.048153e+11
# 1    -6.710987e+10                         3.0  8.962459e+11  8.125611e+11
# 2    -1.142332e+09                         3.0  9.059714e+11  8.127225e+11
# 3     0.000000e+00                         3.0  9.057127e+11  8.127253e+11
# 4    -8.729274e+10                         3.0  9.788347e+11  8.124711e+11
#
#    kewajiban_lain      tabungan  rata_dpk_mingguan    kas_kantor  kas_echannel
# 0    1.419685e+10  7.072647e+11       3.135744e+11  1.928940e+09  2.939100e+09
# 1    1.234062e+10  7.011995e+11       3.135744e+11  2.492322e+11  2.839150e+09
# 2    1.182022e+10  6.922787e+11       3.135744e+11  2.493411e+11  3.387550e+09
# 3    1.199640e+10  6.867224e+11       3.135744e+11  2.493411e+11  3.876950e+09
# 4    1.232962e+10  6.813438e+11       3.135744e+11  2.608817e+11  3.874250e+09

# %%
cash['periode'] = pd.to_datetime(cash['periode'])
cash.sort_values('periode', inplace=True)
cash['kas_kantor_verif'] = cash['kas_kantor'].shift()+cash['cash_in_kantor'] + cash['cash_out_kantor']
cash['kas_echannel_verif'] = cash['kas_echannel'].shift()+cash['cash_in_echannel'] + cash['cash_out_echannel']

# %% [markdown]
# # Data Visualization

# %%
cash.set_index('periode')[['kas_kantor', 'kas_echannel']].plot(subplots=True,
                                                                      figsize=(15, 10))
plt.suptitle('DAILY CASH RATIO:')
plt.show()

# %% [markdown]
# # Data Preparation for Prophet

# %%
daily_kas_kantor = cash[['periode', 'kas_kantor']].rename(
    columns={'periode': 'ds',
             'kas_kantor': 'y'})

# Take 80% data for training

# daily_kas_kantor = cash[['periode', 'kas_kantor']].head(int(len(cash)*(80/100))).rename(
#     columns={'periode': 'ds',
#              'kas_kantor': 'y'})

daily_kas_kantor.head()
# Out:
#           ds             y
# 0 2019-07-31  1.928940e+09
# 1 2019-08-01  2.492322e+11
# 2 2019-08-02  2.493411e+11
# 3 2019-08-03  2.493411e+11
# 4 2019-08-04  2.608817e+11

# %%
daily_kas_echannel = cash[['periode', 'kas_echannel']].rename(
    columns={'periode': 'ds',
             'kas_echannel': 'y'})
# daily_kas_echannel = cash[['periode', 'kas_echannel']].head(int(len(cash)*(80/100))).rename(
#     columns={'periode': 'ds',
#              'kas_echannel': 'y'})

daily_kas_echannel.head()
# Out:
#           ds             y
# 0 2019-07-31  2.939100e+09
# 1 2019-08-01  2.839150e+09
# 2 2019-08-02  3.387550e+09
# 3 2019-08-03  3.876950e+09
# 4 2019-08-04  3.874250e+09

# %% [markdown]
# # Prophet Kas Kantor

# %% [markdown]
# ## Initiate Custom Holiday

# %%
Covid = pd.DataFrame({
    'holiday': 'Covid',
    'ds': pd.to_datetime(['2020-05-19']), # future date, to be forecasted
    'lower_window': -1, # include 27th - 31st December
    'upper_window': 1})

Kemerdekaan = pd.DataFrame({
    'holiday': 'Kemerdekaan',
    'ds': pd.to_datetime(['2020-08-17']), # future date, to be forecasted
    'lower_window': -1, # include 27th - 31st December
    'upper_window': 1})

Natal = pd.DataFrame({
    'holiday': 'Natal',
    'ds': pd.to_datetime(['2020-12-25', # past date, historical data 
                          '2021-12-25']), # future date, to be forecasted
    'lower_window': -10, # include 27th - 31st December
    'upper_window': 0})

holiday_kantor = pd.concat([Covid,Kemerdekaan,Natal], axis=0).reset_index(drop=True)
holiday_kantor
# Out:
#        holiday         ds  lower_window  upper_window
# 0        Covid 2020-05-19            -1             1
# 1  Kemerdekaan 2020-08-17            -1             1
# 2        Natal 2020-12-25           -10             0
# 3        Natal 2021-12-25           -10             0

# %% [markdown]
# ## Prepare Model

# %%
model_holiday_indo_kantor = Prophet(weekly_seasonality=3,
                                    yearly_seasonality=10,
#                                       holidays=holiday_kantor,
                                      changepoint_range=0.8, # default = 0.8 Recommended range: [0.8, 0.95]
                                      changepoint_prior_scale=0.095 # default =0.05 Recommended range: [0.001, 0.5]
                                     )
model_holiday_indo_kantor.add_seasonality(name='monthly', period=30.5, fourier_order=5)
model_holiday_indo_kantor.add_country_holidays(country_name='ID')
model_holiday_indo_kantor.fit(daily_kas_kantor)

# forecasting
future_kantor = model_holiday_indo_kantor.make_future_dataframe(periods=31, freq='D')
forecast_kantor = model_holiday_indo_kantor.predict(future_kantor)

# visualize
model_holiday_indo_kantor.train_holiday_names
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\farha\Anaconda3\envs\tensorflow_gpu\lib\site-packages\fbprophet\hdays.py:105: Warning: We only support Nyepi holiday from 2009 to 2019
#   warnings.warn(warning_msg, Warning)

# %%
plot_plotly(model_holiday_indo_kantor, forecast_kantor)

# %%
plot_components_plotly(model_holiday_indo_kantor, forecast_kantor)

# %% [markdown]
# ## Count Error

# %%
from sklearn.metrics import mean_squared_log_error
np.sqrt(mean_squared_log_error(forecast_kantor['yhat'].head(425),daily_kas_kantor.loc[:,'y']))
# Out:
# 0.1164837791122023

# %% [markdown]
# ## HyperParameter Tuning Ekantor
#
# In this section, we implement a **Grid search algorithm** for model tuning by using for-loop. It builds model for every combination from specified hyperparameters and then evaluate it. The goal is to choose a set of optimal hyperparameters which minimize the forecast error (in this case, smallest RMSLE).
#
# 💡 You can use the code template below, please change it as needed in the section marked by `TO DO`.
#
#
# Click [here](https://facebook.github.io/prophet/docs/diagnostics.html#hyperparameter-tuning) for a list of recommended hyperparameters to be tuned.

# %%
daily_kas_kantor
# Out:
#             ds             y
# 0   2019-07-31  1.928940e+09
# 1   2019-08-01  2.492322e+11
# 2   2019-08-02  2.493411e+11
# 3   2019-08-03  2.493411e+11
# 4   2019-08-04  2.608817e+11
# ..         ...           ...
# 420 2020-09-26  1.123736e+13
# 421 2020-09-27  1.122373e+13
# 422 2020-09-28  1.126813e+13
# 423 2020-09-29  1.134856e+13
# 424 2020-09-30  1.140874e+13
#
# [425 rows x 2 columns]

# %%
from tqdm import tqdm
import itertools
from fbprophet.diagnostics import cross_validation


# Grid search parameters (TO DO: specify possible values)
param_grid = {  
    'changepoint_prior_scale': [0.004, 0.005, 0.006],
    'changepoint_range': [0.8, 0.85, 0.94, 0.95],
    'weekly_seasonality': [3,4,5],
    'yearly_seasonality': [9,10,11]
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmsles = []  # Store the RMSLEs for each params here

# %%
len(all_params)
# Out:
# 108

# %%
# Use cross validation to evaluate all parameters
for params in tqdm(all_params):
    # fitting model
    # (TO DO: change the data and add other components: seasonality, holiday, regressor)
    
    model_ekantor_hyperparameter = Prophet(**params)
    model_ekantor_hyperparameter.add_country_holidays(country_name='ID')
    model_ekantor_hyperparameter.add_seasonality(name='monthly', period=30.5, fourier_order=11)
    model_ekantor_hyperparameter.fit(daily_kas_kantor)

    # forecasting
    forecast_ekantor_hyperparameter = model_ekantor_hyperparameter.predict(future_kantor)

    # Expanding window cross validation (TO DO: use different values)
    cv = cross_validation(model_ekantor_hyperparameter, initial='110 days', period='5 days', horizon='7 days',
                        parallel='processes')

    # Evaluation metrics: RMSLE
    try:
        rmsle = cv.groupby('cutoff').apply(lambda x: mean_squared_log_error(y_true=x['y'],y_pred=x['yhat']) ** 0.5)
        mean_rmsle = rmsle.mean()
        rmsles.append(mean_rmsle)
    except:
        rmsles.append(1)
        continue
# Out:
#   0%|                                                                                          | 0/108 [00:00<?, ?it/s]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C91CF9E48>
#   1%|▊                                                                                 | 1/108 [00:18<33:04, 18.54s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92130EC8>
#   2%|█▌                                                                                | 2/108 [00:37<32:44, 18.53s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C933080C8>
#   3%|██▎                                                                               | 3/108 [00:55<32:08, 18.36s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9234CD48>
#   4%|███                                                                               | 4/108 [01:13<31:53, 18.40s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C935B5288>
#   5%|███▊                                                                              | 5/108 [01:31<31:29, 18.34s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9222EB08>
#   6%|████▌                                                                             | 6/108 [01:51<31:37, 18.60s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C931F0988>
#   6%|█████▎                                                                            | 7/108 [02:09<31:26, 18.68s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C935E2548>
#   7%|██████                                                                            | 8/108 [02:28<31:12, 18.73s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C93563CC8>
#   8%|██████▊                                                                           | 9/108 [02:47<30:59, 18.79s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C91C95EC8>
#   9%|███████▌                                                                         | 10/108 [03:06<30:51, 18.89s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92DA8D88>
#  10%|████████▎                                                                        | 11/108 [03:25<30:23, 18.80s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9234CD48>
#  11%|█████████                                                                        | 12/108 [03:44<30:08, 18.84s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C91C95EC8>
#  12%|█████████▊                                                                       | 13/108 [04:02<29:42, 18.77s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C91D1B588>
#  13%|██████████▌                                                                      | 14/108 [04:21<29:22, 18.75s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92F603C8>
#  14%|███████████▎                                                                     | 15/108 [04:40<29:10, 18.82s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9312FB08>
#  15%|████████████                                                                     | 16/108 [04:59<28:47, 18.78s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92F2CF08>
#  16%|████████████▊                                                                    | 17/108 [05:18<28:30, 18.79s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9225F888>
#  17%|█████████████▌                                                                   | 18/108 [05:36<28:09, 18.77s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019
/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C93110FC8>
#  90%|████████████████████████████████████████████████████████████████████████▊        | 97/108 [30:52<03:29, 19.08s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9234CD48>
#  91%|█████████████████████████████████████████████████████████████████████████▌       | 98/108 [31:11<03:10, 19.09s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C935EB4C8>
#  92%|██████████████████████████████████████████████████████████████████████████▎      | 99/108 [31:30<02:51, 19.09s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C923EDC08>
#  93%|██████████████████████████████████████████████████████████████████████████      | 100/108 [31:49<02:32, 19.12s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C931F9708>
#  94%|██████████████████████████████████████████████████████████████████████████▊     | 101/108 [32:09<02:15, 19.29s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92E953C8>
#  94%|███████████████████████████████████████████████████████████████████████████▌    | 102/108 [32:28<01:55, 19.21s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C91D1B588>
#  95%|████████████████████████████████████████████████████████████████████████████▎   | 103/108 [32:47<01:35, 19.11s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C93322A88>
#  96%|█████████████████████████████████████████████████████████████████████████████   | 104/108 [33:06<01:16, 19.03s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C93550348>
#  97%|█████████████████████████████████████████████████████████████████████████████▊  | 105/108 [33:24<00:57, 19.02s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C921437C8>
#  98%|██████████████████████████████████████████████████████████████████████████████▌ | 106/108 [33:44<00:38, 19.06s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C8FBE7EC8>
#  99%|███████████████████████████████████████████████████████████████████████████████▎| 107/108 [34:03<00:19, 19.07s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9234CD48>
# 100%|████████████████████████████████████████████████████████████████████████████████| 108/108 [34:22<00:00, 19.10s/it]

# %%
tuning_results = pd.DataFrame(all_params)
tuning_results['rmsle'] = rmsles
tuning_results.sort_values(by='rmsle')
# Out:
#      changepoint_prior_scale  changepoint_range  weekly_seasonality  \
# 10                     0.004               0.85                   3
# 13                     0.004               0.85                   4
# 28                     0.004               0.95                   3
# 19                     0.004               0.94                   3
# 1                      0.004               0.80                   3
# ..                       ...                ...                 ...
# 86                     0.006               0.85                   4
# 80                     0.006               0.80                   5
# 96                     0.006               0.94                   5
# 101                    0.006               0.95                   3
# 104                    0.006               0.95                   4
#
#      yearly_seasonality     rmsle
# 10                   10  0.025659
# 13                   10  0.025861
# 28                   10  0.026854
# 19                   10  0.027115
# 1                    10  0.027135
# ..                  ...       ...
# 86                   11  0.033917
# 80                   11  0.034624
# 96                    9  0.034725
# 101                  11  0.034902
# 104                  11  0.036096
#
# [108 rows x 5 columns]

# %%
best_params = all_params[np.argmin(rmsles)]
best_params
# Out:
# {'changepoint_prior_scale': 0.004,
#  'changepoint_range': 0.85,
#  'weekly_seasonality': 3,
#  'yearly_seasonality': 10}

# %%
model_best_kantor = Prophet(**best_params)
model_best_kantor.add_country_holidays(country_name='ID')
model_best_kantor.add_seasonality(name='monthly', period=30.5, fourier_order=5)
model_best_kantor.fit(daily_kas_kantor)


forecast_ekantor_best = model_best_kantor.predict(future_kantor)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019

# %%
#Visualize Result
plot_plotly(model_best_kantor, forecast_ekantor_best)
# Out:
# <div>                            <div id="71c2dbfc-1e9f-416c-a1c3-5db6c9c9edd4" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
11-20T00:00:00", "2019-11-21T00:00:00", "2019-11-22T00:00:00", "2019-11-23T00:00:00", "2019-11-24T00:00:00", "2019-11-25T00:00:00", "2019-11-26T00:00:00", "2019-11-27T00:00:00", "2019-11-28T00:00:00", "2019-11-29T00:00:00", "2019-11-30T00:00:00", "2019-12-01T00:00:00", "2019-12-02T00:00:00", "2019-12-03T00:00:00", "2019-12-04T00:00:00", "2019-12-05T00:00:00", "2019-12-06T00:00:00", "2019-12-07T00:00:00", "2019-12-08T00:00:00", "2019-12-09T00:00:00", "2019-12-10T00:00:00", "2019-12-11T00:00:00", "2019-12-12T00:00:00", "2019-12-13T00:00:00", "2019-12-14T00:00:00", "2019-12-15T00:00:00", "2019-12-16T00:00:00", "2019-12-17T00:00:00", "2019-12-18T00:00:00", "2019-12-19T00:00:00", "2019-12-20T00:00:00", "2019-12-21T00:00:00", "2019-12-22T00:00:00", "2019-12-23T00:00:00", "2019- ...

# %%
# Error with regressor
from sklearn.metrics import mean_squared_log_error
np.sqrt(mean_squared_log_error(daily_kas_kantor.loc[:,'y'], forecast_ekantor_best['yhat'].head(425)))
# Out:
# 0.14400166384415725

# %% [markdown]
# # Prophet Kas E-Channel

# %% [markdown]
# ## Initiate Custom Holiday

# %%
Kemerdekaan = pd.DataFrame({
    'holiday': 'Kemerdekaan',
    'ds': pd.to_datetime(['2020-08-19', # past date, historical data 
                          '2021-08-19']), # future date, to be forecasted
    'lower_window': 0, # include 27th - 31st December
    'upper_window': 4})

Natal = pd.DataFrame({
    'holiday': 'Natal',
    'ds': pd.to_datetime(['2020-12-25', # past date, historical data 
                          '2021-12-25']), # future date, to be forecasted
    'lower_window': -1, # include 27th - 31st December
    'upper_window': 6})

Nyepi = pd.DataFrame({
    'holiday': 'Nyepi',
    'ds': pd.to_datetime(['2020-03-25', # past date, historical data 
                          '2021-03-14']), # future date, to be forecasted
    'lower_window': 0, # include 27th - 31st December
    'upper_window': 1})


holiday_echannel = pd.concat([Kemerdekaan,Natal, Nyepi], axis=0).reset_index(drop=True)
holiday_echannel
# Out:
#        holiday         ds  lower_window  upper_window
# 0  Kemerdekaan 2020-08-19             0             4
# 1  Kemerdekaan 2021-08-19             0             4
# 2        Natal 2020-12-25            -1             6
# 3        Natal 2021-12-25            -1             6
# 4        Nyepi 2020-03-25             0             1
# 5        Nyepi 2021-03-14             0             1

# %%
# See some dates that become outlier

daily_kas_echannel[daily_kas_echannel['y'] > 7e+09]
# Out:
#             ds             y   type
# 383 2020-08-19  7.019300e+09  train
# 384 2020-08-20  8.183350e+09  train
# 385 2020-08-21  8.857000e+09  train
# 386 2020-08-22  9.070650e+09  train
# 387 2020-08-23  7.167200e+09  train

# %% [markdown]
# ## Create the Model

# %%
model_holiday_indo_echannel = Prophet(weekly_seasonality=3,
                                      yearly_seasonality=10,
                                      holidays=holiday_echannel,
                                      changepoint_range=0.8, # default = 0.8 Recommended range: [0.8, 0.95]
                                      changepoint_prior_scale=0.5 # default =0.05 Recommended range: [0.001, 0.5]
                                     )
model_holiday_indo_echannel.add_country_holidays(country_name='ID')
model_holiday_indo_echannel.add_seasonality(name='monthly', period=30.5, fourier_order=11)
model_holiday_indo_echannel.fit(daily_kas_echannel)

# forecasting
future_echannel = model_holiday_indo_echannel.make_future_dataframe(periods=31, freq='D')
forecast_echannel = model_holiday_indo_echannel.predict(future_echannel)

# visualize
model_holiday_indo_echannel.train_holiday_names
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
:00", "2019-12-11T00:00:00", "2019-12-12T00:00:00", "2019-12-13T00:00:00", "2019-12-14T00:00:00", "2019-12-15T00:00:00", "2019-12-16T00:00:00", "2019-12-17T00:00:00", "2019-12-18T00:00:00", "2019-12-19T00:00:00", "2019-12-20T00:00:00", "2019-12-21T00:00:00", "2019-12-22T00:00:00", "2019-12-23T00:00:00", "2019-1 ...

# %% [markdown]
# ## Add Regressor

# %% [markdown]
# ### Prepare Regressor

# %%
## We want to prepare the forecasted regressor in this case total_qty

forecasted_kantor = forecast_ekantor_best[['ds', 'yhat']].tail(31) \
                        .rename(columns={'yhat': 'kas_kantor'})
forecasted_kantor
# Out:
#             ds    kas_kantor
# 425 2020-10-01  1.156505e+13
# 426 2020-10-02  1.158525e+13
# 427 2020-10-03  1.160967e+13
# 428 2020-10-04  1.164384e+13
# 429 2020-10-05  1.167772e+13
# 430 2020-10-06  1.170604e+13
# 431 2020-10-07  1.174968e+13
# 432 2020-10-08  1.186563e+13
# 433 2020-10-09  1.185557e+13
# 434 2020-10-10  1.185222e+13
# 435 2020-10-11  1.186000e+13
# 436 2020-10-12  1.186904e+13
# 437 2020-10-13  1.187805e+13
# 438 2020-10-14  1.191324e+13
# 439 2020-10-15  1.203301e+13
# 440 2020-10-16  1.203400e+13
# 441 2020-10-17  1.204059e+13
# 442 2020-10-18  1.205178e+13
# 443 2020-10-19  1.205847e+13
# 444 2020-10-20  1.206371e+13
# 445 2020-10-21  1.209564e+13
# 446 2020-10-22  1.220894e+13
# 447 2020-10-23  1.219422e+13
# 448 2020-10-24  1.217442e+13
# 449 2020-10-25  1.215584e+13
# 450 2020-10-26  1.214212e+13
# 451 2020-10-27  1.214621e+13
# 452 2020-10-28  1.219683e+13
# 453 2020-10-29  1.234618e+13
# 454 2020-10-30  1.235892e+13
# 455 2020-10-31  1.236996e+13

# %%
# Prepare actual value before forecasted

actual_kantor = daily_kas_kantor.rename(columns={'y': 'kas_kantor'})
actual_kantor
# Out:
#             ds    kas_kantor
# 0   2019-07-31  1.928940e+09
# 1   2019-08-01  2.492322e+11
# 2   2019-08-02  2.493411e+11
# 3   2019-08-03  2.493411e+11
# 4   2019-08-04  2.608817e+11
# ..         ...           ...
# 420 2020-09-26  1.123736e+13
# 421 2020-09-27  1.122373e+13
# 422 2020-09-28  1.126813e+13
# 423 2020-09-29  1.134856e+13
# 424 2020-09-30  1.140874e+13
#
# [425 rows x 2 columns]

# %% [markdown]
# Now, we have to prepare concatenated data of `cash_kantor` as the regressor values of `cash_echannel`:
#
# - First 425  observations: actual values of `cash_kantor`
# - Last 31 observations: forecasted values of `cash_kantor`

# %%
future_with_regressor = pd.concat([actual_kantor, forecasted_kantor])
future_with_regressor
# Out:
#             ds    kas_kantor
# 0   2019-07-31  1.928940e+09
# 1   2019-08-01  2.492322e+11
# 2   2019-08-02  2.493411e+11
# 3   2019-08-03  2.493411e+11
# 4   2019-08-04  2.608817e+11
# ..         ...           ...
# 451 2020-10-27  1.214621e+13
# 452 2020-10-28  1.219683e+13
# 453 2020-10-29  1.234618e+13
# 454 2020-10-30  1.235892e+13
# 455 2020-10-31  1.236996e+13
#
# [456 rows x 2 columns]

# %%
daily_echannel_regressor = cash[['periode', 'kas_echannel', 'kas_kantor']].rename(
    columns={'periode': 'ds',
             'kas_echannel': 'y'})

daily_echannel_regressor.head()
# Out:
#           ds             y    kas_kantor
# 0 2019-07-31  2.939100e+09  1.928940e+09
# 1 2019-08-01  2.839150e+09  2.492322e+11
# 2 2019-08-02  3.387550e+09  2.493411e+11
# 3 2019-08-03  3.876950e+09  2.493411e+11
# 4 2019-08-04  3.874250e+09  2.608817e+11

# %% [markdown]
# ### Prepare New Model with Regressor

# %%
model_echannel_regressor = Prophet(weekly_seasonality=3,
                                      yearly_seasonality=10,
#                                       holidays=holiday_echannel,
                                      changepoint_range=0.95, # default = 0.8 Recommended range: [0.8, 0.95]
                                      changepoint_prior_scale=0.5 # default =0.05 Recommended range: [0.001, 0.5]
                                     )
model_echannel_regressor.add_country_holidays(country_name='ID')
model_echannel_regressor.add_regressor('kas_kantor')
model_echannel_regressor.add_seasonality(name='monthly', period=30.5, fourier_order=5)
model_echannel_regressor.fit(daily_echannel_regressor)

# forecasting
forecast_echannel_regressor = model_echannel_regressor.predict(future_with_regressor)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019

# %%
#Visualize Result
plot_plotly(model_echannel_regressor, forecast_echannel_regressor)
# Out:
# <div>                            <div id="3d7dc26a-4075-4ee9-8e68-32a86df2d056" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d7dc26a-4075-4ee9-8e68-32a86df2d056")) {                    Plotly.newPlot(                        "3d7dc26a-4075-4ee9-8e68-32a86df2d056",                        [{"marker": {"color": "black", "size": 4}, "mode": "markers", "name": "Actual", "type": "scatter", "x": ["2019-07-31T00:00:00", "2019-08-01T00:00:00", "2019-08-02T00:00:00", "2019-08-03T00:00:00", "2019-08-04T00:00:00", "2019-08-05T00:00:00", "2019-08-06T00:00:00", "2019-08-07T00:00:00", "2019-08-08T00:00:00", "2019-08-09T00:00:00", "2019-08-10T00:00:00", "2019-08-11T00:00:00", "2019-08-12T00:00:00", "2019-08-13T00:00:00", "2019-08-14T00:00:00", "2019-08-15T00:00:00", "2019-08-16T00:00:00", "2019-08-17T00:00:00", "2019-08-18T00:00:00", "2019-08-19T00:00:00", "2019-08-20T00:00:00", "2019-08-21T00:00:00", "2019-08-22T00:00:00", "2019-08-23T00:00:00", "2019-08-24T00:00:00", "2019-08-25T00:00:00", "2019-08-26T00:00:00", "2019-08-27T00:00:00", "2019-08-28T00:00:00", "2019-08-29T00:00:00", "2019-08-30T00:00:00", "2019-08-31T00:00:00", "2019-09-01T00:00:00", "2019-09-02T00:00:00", "2019-09-03T00:00:00", "2019-09-04T00:00:00", "2019-09-05T00:00:00", "2019-09-06T00:00:00", "2019-09-07T00:00:00", "2019-09-08T00:00:00", "2019-09-09T00:00:00", "2019-09-10T00:00:00", "2019-09-11T00:00:00", "2019-09-12T00:00:00", "2019-09-13T00:00:00", "2019-09-14T00:00:00", "2019-09-15T00:00:00", "2019-09-16T00:00:00", "2019-09-17T00:00:00", "2019-09-18T00:00:00", "2019-09-19T00:00:00", "2019-09-20T00:00:00", "2019-09-21T00:00:00", "2019-09-22T00:00:00", "2019-09
# Recall how we performed a visual analysis on how the performance of our forecasting model earlier. The technique was in fact, a widely used technique for model cross-validation. It involves splitting our data into two parts:
#
# - Train data is used to train our time series model in order to acquire the underlying patterns such as trend and seasonality.
# - Test data is purposely being kept for us to perform a cross-validation and see how our model perform on an **unseen data**.
#
# The objective is quite clear, is that we are able to acquire a glimpse of what kind of error are we going to expect for the model.

# %% [markdown]
# ### Train-Test Split
#
# Recall that our data has the range of early 2013 to end 2015. Say, we are going to save the records of 2015 as a test data and use the rest for model training. The points in red will now be treated as unseen data and will not be passed in to our Prophet model.

# %%
#@title
# for illustration purposes only
cutoff = pd.to_datetime('2020-09-01')
daily_kas_echannel['type'] = daily_kas_echannel['ds'].apply(
    lambda date: 'train' if date < cutoff else 'test')

plt.figure(figsize=(10, 5))
sns.scatterplot(x='ds', y='y', hue='type', s=5,
                palette=['black', 'red'],
                data=daily_kas_echannel)
plt.axvline(x=cutoff, color='gray', label='cutoff')
plt.legend()
plt.show()

# %%
train = daily_kas_echannel[daily_kas_echannel['ds'] < cutoff]
test = daily_kas_echannel[daily_kas_echannel['ds'] >= cutoff]

print(f'Train size: {train.shape}')
print(f'Test size: {test.shape}')
# Out:
# Train size: (395, 3)
# Test size: (30, 3)

# %%
train
# Out:
#             ds             y   type
# 0   2019-07-31  2.939100e+09  train
# 1   2019-08-01  2.839150e+09  train
# 2   2019-08-02  3.387550e+09  train
# 3   2019-08-03  3.876950e+09  train
# 4   2019-08-04  3.874250e+09  train
# ..         ...           ...    ...
# 390 2020-08-26  4.652250e+09  train
# 391 2020-08-28  5.249900e+09  train
# 392 2020-08-29  6.272800e+09  train
# 393 2020-08-30  5.625400e+09  train
# 394 2020-08-31  5.209300e+09  train
#
# [395 rows x 3 columns]

# %%
model_final_echannel = Prophet(weekly_seasonality=3,
                                      yearly_seasonality=10,
                                      holidays=holiday_echannel,
                                      changepoint_range=0.8, # default = 0.8 Recommended range: [0.8, 0.95]
                                      changepoint_prior_scale=0.5 # default =0.05 Recommended range: [0.001, 0.5]
                                     )
model_final_echannel.add_country_holidays(country_name='ID')
model_final_echannel.add_seasonality(name='monthly', period=30.5, fourier_order=11)
model_final_echannel.fit(train)

# forecasting
future_final_echannel = model_final_echannel.make_future_dataframe(periods=30, freq='D') # 303 days (test size)
forecast_final_echannel = model_final_echannel.predict(future_final_echannel)

# visualize
fig = model_final_echannel.plot(forecast_final_echannel)
plt.scatter(x=test['ds'], y=test['y'], s=10, color='red')
plt.show()
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019

# %%
from sklearn.metrics import mean_squared_log_error
forecast_train = forecast_final_echannel[forecast_final_echannel['ds'] < cutoff]
train_rmsle = mean_squared_log_error(y_true=train['y'],
                                     y_pred=forecast_train['yhat']) ** 0.5
train_rmsle
# Out:
# 0.11304722278033351

# %%
forecast_test = forecast_final_echannel[forecast_final_echannel['ds'] >= cutoff]
test_rmsle = mean_squared_log_error(y_true=test['y'],
                                    y_pred=forecast_test['yhat']) ** 0.5
test_rmsle
# Out:
# 0.12917013158968588

# %% [markdown]
# ## HyperParameter Tuning Echannel
#
# In this section, we implement a **Grid search algorithm** for model tuning by using for-loop. It builds model for every combination from specified hyperparameters and then evaluate it. The goal is to choose a set of optimal hyperparameters which minimize the forecast error (in this case, smallest RMSLE).
#
# 💡 You can use the code template below, please change it as needed in the section marked by `TO DO`.
#
#
# Click [here](https://facebook.github.io/prophet/docs/diagnostics.html#hyperparameter-tuning) for a list of recommended hyperparameters to be tuned.

# %%
daily_echannel_regressor
# Out:
#             ds             y    kas_kantor
# 0   2019-07-31  2.939100e+09  1.928940e+09
# 1   2019-08-01  2.839150e+09  2.492322e+11
# 2   2019-08-02  3.387550e+09  2.493411e+11
# 3   2019-08-03  3.876950e+09  2.493411e+11
# 4   2019-08-04  3.874250e+09  2.608817e+11
# ..         ...           ...           ...
# 420 2020-09-26  5.085800e+09  1.123736e+13
# 421 2020-09-27  4.994300e+09  1.122373e+13
# 422 2020-09-28  5.181900e+09  1.126813e+13
# 423 2020-09-29  5.419050e+09  1.134856e+13
# 424 2020-09-30  5.271900e+09  1.140874e+13
#
# [425 rows x 3 columns]

# %%
from tqdm import tqdm
import itertools
from fbprophet.diagnostics import cross_validation


# Grid search parameters (TO DO: specify possible values)
param_grid = {  
    'changepoint_prior_scale': [0.004, 0.005, 0.006],
    'changepoint_range': [0.8, 0.85, 0.94, 0.95],
    'weekly_seasonality': [3,4,5],
    'yearly_seasonality': [9,10,11]
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmsles = []  # Store the RMSLEs for each params here

# %%
len(all_params)
# Out:
# 108

# %%
# Use cross validation to evaluate all parameters
for params in tqdm(all_params):
    # fitting model
    # (TO DO: change the data and add other components: seasonality, holiday, regressor)
    
    model_echannel_regressor = Prophet(**params,
                                       holidays=holiday_echannel,
                                     )
    model_echannel_regressor.add_country_holidays(country_name='ID')
    model_echannel_regressor.add_regressor('kas_kantor')
    model_echannel_regressor.add_seasonality(name='monthly', period=30.5, fourier_order=5)
    model_echannel_regressor.fit(daily_echannel_regressor)

    # forecasting
    forecast_echannel_regressor = model_echannel_regressor.predict(future_with_regressor)

    # Expanding window cross validation (TO DO: use different values)
    cv = cross_validation(model_echannel_regressor, initial='110 days', period='5 days', horizon='7 days',
                        parallel='processes')

    # Evaluation metrics: RMSLE
    try:
        rmsle = cv.groupby('cutoff').apply(
        lambda x: mean_squared_log_error(y_true=x['y'],
                                           y_pred=x['yhat']) ** 0.5)
        mean_rmsle = rmsle.mean()
        rmsles.append(mean_rmsle)
    except:
        rmsles.append(1)
        continue
# Out:
#   0%|                                                                                          | 0/108 [00:00<?, ?it/s]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C94D9A708>
#   1%|▊                                                                                 | 1/108 [00:20<36:00, 20.19s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C923D0A08>
#   2%|█▌                                                                                | 2/108 [00:43<39:07, 22.15s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C95175948>
#   3%|██▎                                                                               | 3/108 [01:08<41:04, 23.47s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C8FBB04C8>
#   4%|███                                                                               | 4/108 [01:35<42:54, 24.75s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92F2CF48>
#   5%|███▊                                                                              | 5/108 [01:56<39:58, 23.28s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92EB5348>
#   6%|████▌                                                                             | 6/108 [02:16<38:05, 22.41s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C93593288>
#   6%|█████▎                                                                            | 7/108 [02:37<36:35, 21.74s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C93544B48>
#   7%|██████                                                                            | 8/108 [03:12<43:20, 26.01s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92F16BC8>
#   8%|██████▊                                                                           | 9/108 [03:36<41:45, 25.30s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C
/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9219EE88>
#  42%|█████████████████████████████████▊                                               | 45/108 [16:57<23:56, 22.80s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C94EA5D88>
#  43%|██████████████████████████████████▌                                              | 46/108 [17:16<22:27, 21.73s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C947403C8>
#  44%|███████████████████████████████████▎                                             | 47/108 [17:36<21:28, 21.12s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92CE55C8>
#  44%|████████████████████████████████████                                             | 48/108 [17:55<20:42, 20.70s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# ...
#  85%|█████████████████████████████████████████████████████████████████████            | 92/108 [32:26<05:16, 19.75s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C921AC488>
#  86%|█████████████████████████████████████████████████████████████████████▊           | 93/108 [32:46<04:56, 19.75s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9492B908>
#  87%|██████████████████████████████████████████████████████████████████████▌          | 94/108 [33:06<04:37, 19.82s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9234E248>
#  88%|███████████████████████████████████████████████████████████████████████▎         | 95/108 [33:26<04:17, 19.83s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C93179E08>
#  89%|████████████████████████████████████████████████████████████████████████         | 96/108 [33:46<03:58, 19.85s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C932ECD48>
#  90%|████████████████████████████████████████████████████████████████████████▊        | 97/108 [34:05<03:38, 19.83s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92357188>
#  91%|█████████████████████████████████████████████████████████████████████████▌       | 98/108 [34:25<03:18, 19.85s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92EB05C8>
#  92%|██████████████████████████████████████████████████████████████████████████▎      | 99/108 [34:46<03:00, 20.03s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C8F546D88>
#  93%|██████████████████████████████████████████████████████████████████████████      | 100/108 [35:06<02:39, 19.98s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C93514D48>
#  94%|██████████████████████████████████████████████████████████████████████████▊     | 101/108 [35:26<02:20, 20.01s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C921ACB48>
#  94%|███████████████████████████████████████████████████████████████████████████▌    | 102/108 [35:46<01:59, 19.99s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C92357188>
#  95%|████████████████████████████████████████████████████████████████████████████▎   | 103/108 [36:05<01:39, 19.94s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C91D1BA48>
#  96%|█████████████████████████████████████████████████████████████████████████████   | 104/108 [36:25<01:19, 19.91s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C93597748>
#  97%|█████████████████████████████████████████████████████████████████████████████▊  | 105/108 [36:45<00:59, 19.84s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C953A3988>
#  98%|██████████████████████████████████████████████████████████████████████████████▌ | 106/108 [37:05<00:39, 19.80s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C933B9048>
#  99%|███████████████████████████████████████████████████████████████████████████████▎| 107/108 [37:25<00:19, 19.85s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# C:\Users\hutom\anaconda3\envs\tensorflow2\lib\site-packages\fbprophet\hdays.py:105: Warning:
#
# We only support Nyepi holiday from 2009 to 2019
#
# INFO:fbprophet:Making 63 forecasts with cutoffs between 2019-11-18 00:00:00 and 2020-09-23 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x0000019C9222C7C8>
# 100%|████████████████████████████████████████████████████████████████████████████████| 108/108 [37:44<00:00, 20.97s/it]

# %%
tuning_results = pd.DataFrame(all_params)
tuning_results['rmsle'] = rmsles
tuning_results.sort_values(by='rmsle')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-487-3751e4631376> in <module>
#       1 tuning_results = pd.DataFrame(all_params)
# ----> 2 tuning_results['rmsle'] = rmsles
#       3 tuning_results.sort_values(by='rmsle')
#
# ~\anaconda3\envs\tensorflow2\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\envs\tensorflow2\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3237         """
#    3238         self._ensure_valid_index(value)
# -> 3239         value = self._sanitize_column(key, value)
#    3240         NDFrame._set_item(self, key, value)
#    3241
#
# ~\anaconda3\envs\tensorflow2\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3894
#    3895             # turn me into an ndarray
# -> 3896             value = sanitize_index(value, self.index)
#    3897             if not isinstance(value, (np.ndarray, Index)):
#    3898                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\envs\tensorflow2\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     750     if len(data) != len(index):
#     751         raise ValueError(
# --> 752             "Length of values "
#     753             f"({len(data)}) "
#     754             "does not match length of index "
#
# ValueError: Length of values (216) does not match length of index (108)

# %%
best_params = all_params[np.argmin(rmsles)]
best_params

# %%
model_best = Prophet(**best_params,
                     holidays=holiday_echannel)
model_best.add_country_holidays(country_name='ID')
model_best.add_regressor('kas_kantor')
model_best.add_seasonality(name='monthly', period=31.5, fourier_order=5)
model_best.fit(daily_echannel_regressor)


forecast_echannel_best = model_best.predict(future_with_regressor)

# %%
#Visualize Result
plot_plotly(model_best, forecast_echannel_best)

# %%
# Error with regressor
from sklearn.metrics import mean_squared_log_error
np.sqrt(mean_squared_log_error(daily_kas_echannel.loc[:,'y'], forecast_echannel_best['yhat'].head(425)))

# %% [markdown]
# # Create the CSV for submission

# %%
forecast_kantor['yhat'].tail(31)
# Out:
# 425    1.146093e+13
# 426    1.147143e+13
# 427    1.148775e+13
# 428    1.151439e+13
# 429    1.154068e+13
# 430    1.156253e+13
# 431    1.159927e+13
# 432    1.170750e+13
# 433    1.168926e+13
# 434    1.167888e+13
# 435    1.167995e+13
# 436    1.168236e+13
# 437    1.168637e+13
# 438    1.171677e+13
# 439    1.183135e+13
# 440    1.182687e+13
# 441    1.182912e+13
# 442    1.183618e+13
# 443    1.183868e+13
# 444    1.184119e+13
# 445    1.187031e+13
# 446    1.198020e+13
# 447    1.196170e+13
# 448    1.193947e+13
# 449    1.191900e+13
# 450    1.190356e+13
# 451    1.190721e+13
# 452    1.195662e+13
# 453    1.210180e+13
# 454    1.211142e+13
# 455    1.211840e+13
# Name: yhat, dtype: float64

# %%
forecast_echannel_best['yhat'].tail(31)
# Out:
# 425    4.616587e+09
# 426    4.891508e+09
# 427    5.410675e+09
# 428    5.134476e+09
# 429    4.926299e+09
# 430    4.668069e+09
# 431    4.541382e+09
# 432    4.434986e+09
# 433    4.682642e+09
# 434    5.223055e+09
# 435    5.073872e+09
# 436    5.051225e+09
# 437    4.958214e+09
# 438    4.939101e+09
# 439    4.876783e+09
# 440    5.105597e+09
# 441    5.584054e+09
# 442    5.366324e+09
# 443    5.278265e+09
# 444    5.098839e+09
# 445    4.976465e+09
# 446    4.850992e+09
# 447    5.081374e+09
# 448    5.548659e+09
# 449    5.219058e+09
# 450    4.970045e+09
# 451    4.740183e+09
# 452    4.735977e+09
# 453    4.676744e+09
# 454    5.013043e+09
# 455    5.414806e+09
# Name: yhat, dtype: float64

# %%
submission = pd.concat([forecast_ekantor_best['yhat'].tail(31), forecast_echannel_best['yhat'].tail(31)], axis=0).reset_index(drop=True)

# %%
submission
# Out:
# 0     1.156505e+13
# 1     1.158525e+13
# 2     1.160967e+13
# 3     1.164384e+13
# 4     1.167772e+13
#           ...
# 57    4.740183e+09
# 58    4.735977e+09
# 59    4.676744e+09
# 60    5.013043e+09
# 61    5.414806e+09
# Name: yhat, Length: 62, dtype: float64

# %%
submission.to_csv('both hyperparameter tuning_13 February 2021.csv',index_label='index',header=['value'])
